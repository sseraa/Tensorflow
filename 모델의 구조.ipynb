# %% [markdown]
# github csv url: https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/lemonade.csv

# %%
# 라이브러리 사용
import tensorflow as tf
import pandas as pd

# %%
# 데이터 준비 - 독립, 종속 나눠서
파일경로 = "https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/lemonade.csv"
data=pd.read_csv(파일경로)
data.head()
# Out:
#    온도  판매량
# 0  20   40
# 1  21   42
# 2  22   44
# 3  23   46
# 4  24   48

# %%
# 독립, 종속변수
de = data[['온도']]
ind = data[['판매량']]
print(de.shape, ind.shape)
# Out:
# (6, 1) (6, 1)

# %%
# 모델 만들기
X = tf.keras.layers.Input(shape=[1])
Y = tf.keras.layers.Dense(1)(X)
model = tf.keras.models.Model(X,Y)
model.compile(loss='mse')

# %%
# 모델 학습
model.fit(de,ind, epochs=10) # verbose=0 ; 출력 끔
# Out:
# Epoch 1/10
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0071
# Epoch 2/10
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0071
# Epoch 3/10
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0071
# Epoch 4/10
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0071
# Epoch 5/10
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0071
# Epoch 6/10
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0071
# Epoch 7/10
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0071
# Epoch 8/10
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0071
# Epoch 9/10
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0071
# Epoch 10/10
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0071

# %%
#모델을 이용
model.predict(de)
# Out:
# array([[40.138264],
#        [42.09006 ],
#        [44.04186 ],
#        [45.993656],
#        [47.945454],
#        [49.89725 ]], dtype=float32)

# %%
model.predict([[15]])
# Out:
# array([[30.379272]], dtype=float32)
